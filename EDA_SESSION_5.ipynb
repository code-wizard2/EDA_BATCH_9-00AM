# %% [markdown]
# $$numerical vs numerical$$

# %%
- to understand numerical columns relation we need to plot scatter plots

- scatter plots gives the relation between two numerical columns

- bar chart or pie chart, histogram, scatter plots

-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\mohdb\Documents\naresh it\eda\Visadataset.csv")
visa_df.head()
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
cat_columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# #plt.scatter#

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
# step-1 read one numerical columns
# step-2 read secound numerical problem
# step-3 apply the scatter plot

# %%
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
col3=visa_df['prevailing_wage']
plt.scatter(col1,col2)

# %%
coll=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
col3=visa_df['prevailing_wage']
plt.figure(figsize=(14,3))
plt.subplot(1,3,1).scatter (coll,col2)
plt.xlabel('no_of_employees')
plt.ylabel('yr_of_estab')
plt.subplot(1,3,2).scatter (coll,col2)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
plt.subplot(1,3,3).scatter (coll,col2)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
# Out:
# Text(0, 0.5, 'prevailing_wage')

# %%
- Implement the Covariance function

- covariance vs Correlation

        - Covariance will tell about the columns have relation or not

        - Covariance will explain about relation status

            - postive relation

            - negative relation

            - no relation

        - Correlation tells about how much relation between two variables

        - It denotes tells about how much reltion between two variable

        -It denotes with 'r'
        
        - r value from -1 to 1
        
        - -1 to 0 indicates

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# $$heat-map$$

# %% [markdown]
# - heat map is one of the important visualization method, to show the matrix
#
# - it is uber **seaborn** package
#
# - in every matrix we have heightest values and lowest values available
#
# - heat meap will give colour visuliation
#
# - also it provides color

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='hsv')
plt.show()

# %%
- by seeing the graph we might not say the relation status

- it is best pratice get the percentage of relation using correlation

- all 3 columns having approximately zero percentage of relation

- which indicates all the columns having no relation

- no relation means indepentant each other

- in mal we expert the input columns should be independent each o
